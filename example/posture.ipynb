# %%
from common.display import display_posture_all
from common.config import ConfigPosture

config = ConfigPosture()
config.date = "2024_03_02"

display_posture_all(config.record_dir, config.success_distance_thresholds)
# Out:
#        Success Threshold (deg)     IKFlow     NodeIK       PAIK
# count                14.000000  14.000000  14.000000  14.000000
# mean                150.000000  32.216842  11.637660  66.729865
# std                  83.666003  18.940765  16.087323  22.975903
# min                  20.000000   4.459800   0.000000  15.872867
# 25%                  85.000000  18.579375   0.084396  55.985804
# 50%                 150.000000  30.782825   2.901000  74.191150
# 75%                 215.000000  42.887796  18.376829  83.077358
# max                 280.000000  69.749483  48.692117  92.334050
